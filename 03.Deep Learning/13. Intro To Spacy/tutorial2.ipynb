# %%
import datasets

import torchtext
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from torchtext.datasets import AmazonReviewFull
train, test = AmazonReviewFull()
label_list = []
review_list = []

for label, rev in train:
    label_list.append(label)
    review_list.append(rev)

print(label_list[:5], review_list[:5])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\rnr31\Documents\GitHub\Data_Science_2022\03.Deep Learning\13. Intro To Spacy\tutorial2.ipynb Cell 2' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Data_Science_2022/03.Deep%20Learning/13.%20Intro%20To%20Spacy/tutorial2.ipynb#ch0000001?line=2'>3</a> label_list = []
#       <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Data_Science_2022/03.Deep%20Learning/13.%20Intro%20To%20Spacy/tutorial2.ipynb#ch0000001?line=3'>4</a> review_list = []
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Data_Science_2022/03.Deep%20Learning/13.%20Intro%20To%20Spacy/tutorial2.ipynb#ch0000001?line=5'>6</a> for label, rev in train:
#       <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Data_Science_2022/03.Deep%20Learning/13.%20Intro%20To%20Spacy/tutorial2.ipynb#ch0000001?line=6'>7</a>     label_list.append(label)
#       <a href='vscode-notebook-cell:/c%3A/Users/rnr31/Documents/GitHub/Data_Science_2022/03.Deep%20Learning/13.%20Intro%20To%20Spacy/tutorial2.ipynb#ch0000001?line=7'>8</a>     review_list.append(rev)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\callable.py:112, in MapperIterDataPipe.__iter__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=110'>111</a> def __iter__(self) -> Iterator[T_co]:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=111'>112</a>     for data in self.datapipe:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=112'>113</a>         yield self._apply_fn(data)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torchdata\datapipes\iter\util\plain_text_reader.py:148, in _CSVBaseParserIterDataPipe.__iter__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=146'>147</a> def __iter__(self) -> Iterator[Union[D, Tuple[str, D]]]:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=147'>148</a>     for path, file in self.source_datapipe:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=148'>149</a>         stream = self._helper.skip_lines(file)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=149'>150</a>         stream = self._helper.decode(stream)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\fileopener.py:60, in FileOpenerIterDataPipe.__iter__(self)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/fileopener.py?line=58'>59</a> def __iter__(self):
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/fileopener.py?line=59'>60</a>     yield from get_file_binaries_from_pathnames(self.datapipe, self.mode, self.encoding)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\utils\common.py:85, in get_file_binaries_from_pathnames(pathnames, mode, encoding)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/utils/common.py?line=81'>82</a> if mode in ('b', 't'):
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/utils/common.py?line=82'>83</a>     mode = 'r' + mode
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/utils/common.py?line=84'>85</a> for pathname in pathnames:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/utils/common.py?line=85'>86</a>     if not isinstance(pathname, str):
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/utils/common.py?line=86'>87</a>         raise TypeError("Expected string type for pathname, but got {}"
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/utils/common.py?line=87'>88</a>                         .format(type(pathname)))
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\combining.py:46, in ConcaterIterDataPipe.__iter__(self)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=43'>44</a> def __iter__(self) -> Iterator:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=44'>45</a>     for dp in self.datapipes:
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=45'>46</a>         for data in dp:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=46'>47</a>             yield data
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\filelister.py:51, in FileListerIterDataPipe.__iter__(self)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/filelister.py?line=49'>50</a> def __iter__(self) -> Iterator[str] :
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/filelister.py?line=50'>51</a>     for path in self.datapipe:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/filelister.py?line=51'>52</a>         yield from get_file_pathnames_from_root(path, self.masks, self.recursive, self.abspath, self.non_deterministic)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\grouping.py:140, in UnBatcherIterDataPipe.__iter__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/grouping.py?line=138'>139</a> def __iter__(self):
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/grouping.py?line=139'>140</a>     for element in self.datapipe:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/grouping.py?line=140'>141</a>         for i in self._dive(element, unbatch_level=self.unbatch_level):
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/grouping.py?line=141'>142</a>             yield i
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\callable.py:112, in MapperIterDataPipe.__iter__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=110'>111</a> def __iter__(self) -> Iterator[T_co]:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=111'>112</a>     for data in self.datapipe:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=112'>113</a>         yield self._apply_fn(data)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:356, in hook_iterator.<locals>.IteratorDecorator.__next__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=353'>354</a> def __next__(self):
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=354'>355</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=355'>356</a>         return next(self.iterator)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\combining.py:190, in _ChildDataPipe.get_generator_by_instance(self, instance_id)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=188'>189</a> def get_generator_by_instance(self, instance_id: int):
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=189'>190</a>     yield from self.main_datapipe.get_next_element_by_instance(self.instance_id)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\combining.py:301, in _DemultiplexerIterDataPipe.get_next_element_by_instance(self, instance_id)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=298'>299</a> else:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=299'>300</a>     try:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=300'>301</a>         yield self._find_next(instance_id)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=301'>302</a>     except StopIteration:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=302'>303</a>         stop = True
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\combining.py:275, in _DemultiplexerIterDataPipe._find_next(self, instance_id)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=270'>271</a> if self._datapipe_iterator is None:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=271'>272</a>     raise ValueError(
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=272'>273</a>         "_datapipe_iterator has not been set, likely because this private method is called directly "
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=273'>274</a>         "without invoking get_next_element_by_instance() first.")
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=274'>275</a> value = next(self._datapipe_iterator)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=275'>276</a> classification = self.classifier_fn(value)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=276'>277</a> if classification is None and self.drop_none:
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\combining.py:46, in ConcaterIterDataPipe.__iter__(self)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=43'>44</a> def __iter__(self) -> Iterator:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=44'>45</a>     for dp in self.datapipes:
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=45'>46</a>         for data in dp:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/combining.py?line=46'>47</a>             yield data
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torchdata\datapipes\iter\util\saver.py:48, in SaverIterDataPipe.__iter__(self)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/saver.py?line=46'>47</a> def __iter__(self) -> Iterator[str]:
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/saver.py?line=47'>48</a>     for filepath, data in self.source_datapipe:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/saver.py?line=48'>49</a>         if self.fn is not None:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/saver.py?line=49'>50</a>             filepath = self.fn(filepath)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torchdata\datapipes\iter\util\hashchecker.py:62, in HashCheckerIterDataPipe.__iter__(self)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=60'>61</a> def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=61'>62</a>     for file_name, data in self.source_datapipe:
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=62'>63</a>         if self.hash_type == "sha256":
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=63'>64</a>             hash_func = hashlib.sha256()
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\callable.py:112, in MapperIterDataPipe.__iter__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=110'>111</a> def __iter__(self) -> Iterator[T_co]:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=111'>112</a>     for data in self.datapipe:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=112'>113</a>         yield self._apply_fn(data)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\datapipes\iter\callable.py:112, in MapperIterDataPipe.__iter__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=110'>111</a> def __iter__(self) -> Iterator[T_co]:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=111'>112</a>     for data in self.datapipe:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/datapipes/iter/callable.py?line=112'>113</a>         yield self._apply_fn(data)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torch\utils\data\_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torchdata\datapipes\iter\load\online.py:121, in GDriveReaderDataPipe.__iter__(self)
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=118'>119</a> def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
#     <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=119'>120</a>     for url in self.source_datapipe:
# --> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=120'>121</a>         yield _get_response_from_google_drive(url, timeout=self.timeout)
#
# File c:\Users\rnr31\anaconda3\envs\pipcv22\lib\site-packages\torchdata\datapipes\iter\load\online.py:85, in _get_response_from_google_drive(url, timeout)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=81'>82</a>     response = session.get(url, timeout=timeout, stream=True)
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=83'>84</a> if "content-disposition" not in response.headers:
# ---> <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=84'>85</a>     raise RuntimeError("Internal error: headers don't contain content-disposition.")
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=86'>87</a> filename = re.findall('filename="(.+)"', response.headers["content-disposition"])
#      <a href='file:///c%3A/Users/rnr31/anaconda3/envs/pipcv22/lib/site-packages/torchdata/datapipes/iter/load/online.py?line=87'>88</a> if filename is None:
#
# RuntimeError: Internal error: headers don't contain content-disposition.
