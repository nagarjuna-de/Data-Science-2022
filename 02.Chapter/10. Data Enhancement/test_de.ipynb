# %%
import numpy    as np
from numpy.testing._private.utils import decorate_methods
import pandas   as pd
import seaborn  as sns
import matplotlib.pyplot as plt
import sklearn  as skl
import time

from sklearn.pipeline import Pipeline      # Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, PowerTransformer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn import set_config
set_config(display='diagram') # Useful for display the pipeline

from sklearn.tree          import DecisionTreeRegressor
from sklearn.ensemble      import RandomForestRegressor
from sklearn.ensemble      import ExtraTreesRegressor
from sklearn.ensemble      import AdaBoostRegressor
from sklearn.ensemble      import GradientBoostingRegressor
from xgboost               import XGBRegressor
from lightgbm              import LGBMRegressor
from catboost              import CatBoostRegressor

# %%
data = pd.read_csv(r'data\london_merged.csv')
data['year'] = data['timestamp'].apply(lambda row: row[:4])
data['month'] = data['timestamp'].apply(lambda row: row.split('-')[2][:2] )
data['hour'] = data['timestamp'].apply(lambda row: row.split(':')[0][-2:] )
data.drop('timestamp', axis=1, inplace=True)
data.head()
# Out:
#    cnt   t1   t2    hum  wind_speed  weather_code  is_holiday  is_weekend  \
# 0  182  3.0  2.0   93.0         6.0           3.0         0.0         1.0
# 1  138  3.0  2.5   93.0         5.0           1.0         0.0         1.0
# 2  134  2.5  2.5   96.5         0.0           1.0         0.0         1.0
# 3   72  2.0  2.0  100.0         0.0           1.0         0.0         1.0
# 4   47  2.0  0.0   93.0         6.5           1.0         0.0         1.0
#
#    season  year month hour
# 0     3.0  2015    04   00
# 1     3.0  2015    04   01
# 2     3.0  2015    04   02
# 3     3.0  2015    04   03
# 4     3.0  2015    04   04

# %%
def data_enhancement(data):
    
    gen_data = data
    
    for season in data['season'].unique():
        seasonal_data =  gen_data[gen_data['season'] == season]
        hum_std = seasonal_data['hum'].std()
        wind_speed_std = seasonal_data['wind_speed'].std()
        t1_std = seasonal_data['t1'].std()
        t2_std = seasonal_data['t2'].std()
        
        for i in gen_data[gen_data['season'] == season].index:
            if np.random.randint(2) == 1:
                gen_data['hum'].values[i] += hum_std/10
            else:
                gen_data['hum'].values[i] -= hum_std/10
                
            if np.random.randint(2) == 1:
                gen_data['wind_speed'].values[i] += wind_speed_std/10
            else:
                gen_data['wind_speed'].values[i] -= wind_speed_std/10
                
            if np.random.randint(2) == 1:
                gen_data['t1'].values[i] += t1_std/10
            else:
                gen_data['t1'].values[i] -= t1_std/10
                
            if np.random.randint(2) == 1:
                gen_data['t2'].values[i] += t2_std/10
            else:
                gen_data['t2'].values[i] -= t2_std/10

    return gen_data

print(data.head(3))
gen = data_enhancement(data)
print(gen.head(3) )
# Out:
#    cnt   t1   t2   hum  wind_speed  weather_code  is_holiday  is_weekend  \
# 0  182  3.0  2.0  93.0         6.0           3.0         0.0         1.0
# 1  138  3.0  2.5  93.0         5.0           1.0         0.0         1.0
# 2  134  2.5  2.5  96.5         0.0           1.0         0.0         1.0
#
#    season  year month hour
# 0     3.0  2015    04   00
# 1     3.0  2015    04   01
# 2     3.0  2015    04   02
#    cnt        t1       t2        hum  wind_speed  weather_code  is_holiday  \
# 0  182  3.379372  1.51169  94.089517    5.109105           3.0         0.0
# 1  138  3.379372  2.98831  91.910483    4.109105           1.0         0.0
# 2  134  2.879372  2.98831  97.589517   -0.890895           1.0         0.0
#
#    is_weekend  season  year month hour
# 0         1.0     3.0  2015    04   00
# 1         1.0     3.0  2015    04   01
# 2         1.0     3.0  2015    04   02

# %%
y = data['cnt']
x = data.drop(['cnt'], axis=1)


cat_vars = ['season','is_weekend','is_holiday','year','month','weather_code']
num_vars = ['t1','t2','hum','wind_speed']


x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2,random_state=0) # Recommended for reproducibility

extra_sample = gen.sample(gen.shape[0] // 3)
x_train = pd.concat([x_train, extra_sample.drop(['cnt'], axis=1 ) ])
y_train = pd.concat([y_train, extra_sample['cnt'] ])

transformer = PowerTransformer()
y_train = transformer.fit_transform(y_train.values.reshape(-1,1))
y_val = transformer.transform(y_val.values.reshape(-1,1))

# %%
num_4_treeModels = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value=-9999)),
])

cat_4_treeModels = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('ordinal', OrdinalEncoder()) # handle_unknown='ignore' ONLY IN VERSION 0.24
])

tree_prepro = ColumnTransformer(transformers=[
    ('num', num_4_treeModels, num_vars),
    ('cat', cat_4_treeModels, cat_vars),
], remainder='drop') # Drop other vars not specified in num_vars or cat_vars

# %%
tree_classifiers = {
  "Decision Tree": DecisionTreeRegressor(),
  "Extra Trees":   ExtraTreesRegressor(n_estimators=100),
  "Random Forest": RandomForestRegressor(n_estimators=100),
  "AdaBoost":      AdaBoostRegressor(n_estimators=100),
  "Skl GBM":       GradientBoostingRegressor(n_estimators=100),
  "XGBoost":       XGBRegressor(n_estimators=100),
  "LightGBM":      LGBMRegressor(n_estimators=100),
  "CatBoost":      CatBoostRegressor(n_estimators=100),
}

tree_classifiers = {name: make_pipeline(tree_prepro, model) for name, model in tree_classifiers.items()}

results = pd.DataFrame({'Model': [],'r_score':[], 'MSE': [], 'MAB': [], " % error": [], 'Time': []})

# %%
rang = abs(y_train.max()) + abs(y_train.min())
for model_name, model in tree_classifiers.items():
    
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
        
    pred = model.predict(x_val)
    
    results = results.append({"Model":    model_name,
                              "r_score": r2_score(y_val, pred),
                              "MSE": mean_squared_error(y_val, pred),

                              "MAB": mean_absolute_error(y_val, pred),
                              " % error": mean_squared_error(y_val, pred) / rang,
                              "Time":     total_time},
                              ignore_index=True)

results_ord = results.sort_values(by=['MSE'], ascending=True, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['MSE', 'MAE'], vmin=0, vmax=100, color='#5fba7d')

print(results_ord)
# Out:
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\pipeline.py:346: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rnr31\anaconda3\envs\ds22\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Learning rate set to 0.42641
# 0:	learn: 0.8876335	total: 184ms	remaining: 18.2s
# 1:	learn: 0.8420592	total: 192ms	remaining: 9.42s
# 2:	learn: 0.8188574	total: 201ms	remaining: 6.5s
# 3:	learn: 0.8041772	total: 206ms	remaining: 4.94s
# 4:	learn: 0.7965034	total: 211ms	remaining: 4.02s
# 5:	learn: 0.7903478	total: 218ms	remaining: 3.42s
# 6:	learn: 0.7854029	total: 225ms	remaining: 2.99s
# 7:	learn: 0.7827981	total: 231ms	remaining: 2.66s
# 8:	learn: 0.7797221	total: 237ms	remaining: 2.4s
# 9:	learn: 0.7772832	total: 243ms	remaining: 2.19s
# 10:	learn: 0.7757979	total: 249ms	remaining: 2.02s
# 11:	learn: 0.7740608	total: 256ms	remaining: 1.88s
# 12:	learn: 0.7727595	total: 263ms	remaining: 1.76s
# 13:	learn: 0.7711789	total: 269ms	remaining: 1.65s
# 14:	learn: 0.7706299	total: 278ms	remaining: 1.57s
# 15:	learn: 0.7686473	total: 285ms	remaining: 1.49s
# 16:	learn: 0.7667073	total: 292ms	remaining: 1.43s
# 17:	learn: 0.7642243	total: 298ms	remaining: 1.36s
# 18:	learn: 0.7633221	total: 303ms	remaining: 1.29s
# 19:	learn: 0.7610187	total: 310ms	remaining: 1.24s
# 20:	learn: 0.7592283	total: 317ms	remaining: 1.19s
# 21:	learn: 0.7581859	total: 330ms	remaining: 1.17s
# 22:	learn: 0.7560024	total: 336ms	remaining: 1.13s
# 23:	learn: 0.7549972	total: 346ms	remaining: 1.09s
# 24:	learn: 0.7541029	total: 354ms	remaining: 1.06s
# 25:	learn: 0.7529146	total: 361ms	remaining: 1.03s
# 26:	learn: 0.7517264	total: 369ms	remaining: 997ms
# 27:	learn: 0.7505452	total: 375ms	remaining: 963ms
# 28:	learn: 0.7492457	total: 381ms	remaining: 932ms
# 29:	learn: 0.7479757	total: 387ms	remaining: 902ms
# 30:	learn: 0.7468786	total: 394ms	remaining: 877ms
# 31:	learn: 0.7456849	total: 400ms	remaining: 850ms
# 32:	learn: 0.7441794	total: 406ms	remaining: 824ms
# 33:	learn: 0.7431467	total: 413ms	remaining: 802ms
# 34:	learn: 0.7417962	total: 423ms	remaining: 785ms
# 35:	learn: 0.7407243	total: 431ms	remaining: 766ms
# 36:	learn: 0.7389721	total: 437ms	remaining: 745ms
# 37:	learn: 0.7376560	total: 444ms	remaining: 724ms
# 38:	learn: 0.7362099	total: 449ms	remaining: 703ms
# 39:	learn: 0.7348532	total: 456ms	remaining: 684ms
# 40:	learn: 0.7336673	total: 465ms	remaining: 669ms
# 41:	learn: 0.7328058	total: 471ms	remaining: 650ms
# 42:	learn: 0.7312461	total: 478ms	remaining: 634ms
# 43:	learn: 0.7300007	total: 486ms	remaining: 619ms
# 44:	learn: 0.7288553	total: 491ms	remaining: 600ms
# 45:	learn: 0.7279320	total: 499ms	remaining: 586ms
# 46:	learn: 0.7268574	total: 505ms	remaining: 570ms
# 47:	learn: 0.7253966	total: 511ms	remaining: 554ms
# 48:	learn: 0.7245609	total: 518ms	remaining: 539ms
# 49:	learn: 0.7240021	total: 525ms	remaining: 525ms
# 50:	learn: 0.7233057	total: 532ms	remaining: 511ms
# 51:	learn: 0.7220472	total: 540ms	remaining: 499ms
# 52:	learn: 0.7210147	total: 550ms	remaining: 488ms
# 53:	learn: 0.7199731	total: 555ms	remaining: 473ms
# 54:	learn: 0.7190768	total: 560ms	remaining: 459ms
# 55:	learn: 0.7183481	total: 570ms	remaining: 448ms
# 56:	learn: 0.7178923	total: 576ms	remaining: 435ms
# 57:	learn: 0.7165019	total: 585ms	remaining: 424ms
# 58:	learn: 0.7156365	total: 593ms	remaining: 412ms
# 59:	learn: 0.7147342	total: 598ms	remaining: 399ms
# 60:	learn: 0.7132806	total: 608ms	remaining: 389ms
# 61:	learn: 0.7122941	total: 613ms	remaining: 376ms
# 62:	learn: 0.7115565	total: 619ms	remaining: 363ms
# 63:	learn: 0.7104890	total: 625ms	remaining: 352ms
# 64:	learn: 0.7096078	total: 634ms	remaining: 341ms
# 65:	learn: 0.7089454	total: 642ms	remaining: 331ms
# 66:	learn: 0.7080910	total: 648ms	remaining: 319ms
# 67:	learn: 0.7073261	total: 657ms	remaining: 309ms
# 68:	learn: 0.7068264	total: 665ms	remaining: 299ms
# 69:	learn: 0.7055552	total: 674ms	remaining: 289ms
# 70:	learn: 0.7050895	total: 682ms	remaining: 278ms
# 71:	learn: 0.7044042	total: 690ms	remaining: 268ms
# 72:	learn: 0.7035925	total: 697ms	remaining: 258ms
# 73:	learn: 0.7030221	total: 705ms	remaining: 248ms
# 74:	learn: 0.7021398	total: 710ms	remaining: 237ms
# 75:	learn: 0.7012961	total: 715ms	remaining: 226ms
# 76:	learn: 0.7005261	total: 723ms	remaining: 216ms
# 77:	learn: 0.7002514	total: 730ms	remaining: 206ms
# 78:	learn: 0.6994252	total: 739ms	remaining: 196ms
# 79:	learn: 0.6986013	total: 745ms	remaining: 186ms
# 80:	learn: 0.6977132	total: 752ms	remaining: 176ms
# 81:	learn: 0.6969885	total: 759ms	remaining: 167ms
# 82:	learn: 0.6964194	total: 767ms	remaining: 157ms
# 83:	learn: 0.6954353	total: 772ms	remaining: 147ms
# 84:	learn: 0.6946800	total: 778ms	remaining: 137ms
# 85:	learn: 0.6942229	total: 784ms	remaining: 128ms
# 86:	learn: 0.6932279	total: 789ms	remaining: 118ms
# 87:	learn: 0.6928487	total: 794ms	remaining: 108ms
# 88:	learn: 0.6916483	total: 807ms	remaining: 99.7ms
# 89:	learn: 0.6907538	total: 812ms	remaining: 90.2ms
# 90:	learn: 0.6896419	total: 820ms	remaining: 81.1ms
# 91:	learn: 0.6886130	total: 825ms	remaining: 71.7ms
# 92:	learn: 0.6880570	total: 832ms	remaining: 62.6ms
# 93:	learn: 0.6876484	total: 837ms	remaining: 53.4ms
# 94:	learn: 0.6871936	total: 847ms	remaining: 44.6ms
# 95:	learn: 0.6864637	total: 854ms	remaining: 35.6ms
# 96:	learn: 0.6853840	total: 862ms	remaining: 26.6ms
# 97:	learn: 0.6848039	total: 866ms	remaining: 17.7ms
# 98:	learn: 0.6837914	total: 872ms	remaining: 8.81ms
# 99:	learn: 0.6834189	total: 878ms	remaining: 0us
#            Model   r_score       MSE       MAB   % error      Time
# 1    Extra Trees  0.619481  0.379716  0.371464  0.068800  4.593081
# 2  Random Forest  0.580571  0.418544  0.454154  0.075835  7.022218
# 3        XGBoost  0.471720  0.527165  0.549387  0.095515  1.580891
# 4       LightGBM  0.436336  0.562475  0.578765  0.101913  0.573351
# 5       CatBoost  0.427897  0.570896  0.579297  0.103439  1.292781
# 6        Skl GBM  0.376430  0.622255  0.612694  0.112744  2.009511
# 7       AdaBoost  0.305429  0.693106  0.663385  0.125582  0.616376
# 8  Decision Tree  0.275407  0.723064  0.505918  0.131010  0.231952

# %%
results_ord
# Out:
#            Model   r_score       MSE       MAB   % error      Time
# 1    Extra Trees  0.619481  0.379716  0.371464  0.068800  4.593081
# 2  Random Forest  0.580571  0.418544  0.454154  0.075835  7.022218
# 3        XGBoost  0.471720  0.527165  0.549387  0.095515  1.580891
# 4       LightGBM  0.436336  0.562475  0.578765  0.101913  0.573351
# 5       CatBoost  0.427897  0.570896  0.579297  0.103439  1.292781
# 6        Skl GBM  0.376430  0.622255  0.612694  0.112744  2.009511
# 7       AdaBoost  0.305429  0.693106  0.663385  0.125582  0.616376
# 8  Decision Tree  0.275407  0.723064  0.505918  0.131010  0.231952
